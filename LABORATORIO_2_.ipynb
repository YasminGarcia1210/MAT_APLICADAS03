# %% [markdown]
# <a href="https://colab.research.google.com/github/YasminGarcia1210/MAT_APLICADAS03/blob/main/LABORATORIO_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src=http://www.acofi.edu.co/eiei2016/wp-content/uploads/2016/09/Logo-Universidad-ICESI.jpg width="150" height="100" align="center">
#
# #**<big><big>Matemáticas Aplicadas I</big></big><br><small> FIDCA- Facultad de Ingeniería, diseño y ciencias aplicadas </small><br><small> LABORATORIO #2  SUCESIONES y SERIES. </small>**

# %% [markdown]
# # Pregunta  1
#
# A María le recetan un medicamento llamado Benazepril a 50 mg. El medicamento se debe tomar cada 4 horas. Su cuerpo va absorbiendo **gradualmente** el medicamento, tal que 4 horas después de su toma, el 50% del medicamento permanece activo en su cuerpo.
#
# a. ¿Cuánto medicamento permanece activo en el cuerpo de María 12 horas después de la primera toma?
#
# b. ¿Cuánto medicamento está activo en el cuerpo de María 10 días después de su primera toma? (suponga que cada día María toma 6 veces su medicamento cada día)
#
# c. Construya una sucesión que modele el proceso y grafique. ¿Qué se puede evidenciar en la gráfica?
#
# d. María cree que, si toma el medicamento más seguido, se puede obtener un mejor resultado, por tanto, decide tomarlo cada dos horas. ¿Qué ocurre con la eficacia del medicamento si altera los horarios de la toma? Construya una tabla y una gráfica, primero separada y luego en la misma cuadricula con el caso anterior cuando la toma es cada 4 horas.
# Escriba una breve conclusión acerca de la eficacia del medicamento y de los riesgos que se presentan cuando se modifica el horario de la toma de un medicamento

# %% [markdown]
# # Pregunta 2
#
# **Un clásico matemático** Considere un triángulo equilátero con lados de longitud 1 como se muestra en la FIGURA a).  Como se muestra en la figura b), sobre cada uno de los tres lados del triángulo se construye otro triángulo equilátero con lados de longitud Como se señala en las figuras c) y d), se continúa esta construcción: se construyen triángulos equiláteros sobre los lados de cada nuevo triángulo previo de modo tal que la longitud de los lados del nuevo triángulo es la longitud de los lados del triángulo anterior.
# Considere que el perímetro de la primera figura es P1, el perímetro de la
# segunda figura P2, y así en lo sucesivo.
#
# ![copo .png](data:image/png;base64,...)

# %% [markdown]
# [IMAGEN](https://es.wikipedia.org/wiki/Copo_de_nieve_de_Koch#/media/Archivo:Von_Koch_curve.gif) Gif de la curva de Koch

# %% [markdown]
# **Responda**
#
# a) Encuentre los valores de P1, P2, P3 y P4.
#
# b) Encuentre la fórmula para el perímetro Pn de la n-ésima figura.
#
# c) ¿Cuál es el $lim_{n → \infty } Pn$ ?
#
# **El perímetro de la región similar a un copo de nieve que se obtuvo dejando se
# llama curva del copo de nieve de Koch y fue inventada en 1904 por el matemático sueco Helge von Koch (1870-1924)

# %% [markdown]
# # Pregunta 3
#
# Se fórmula la recursión $F_n$
#
# si se define $F_{n+1}= F_n +F_{n-1}$ donde $F_1=1$ y $F_2=1$
#
# Dividiendo todo por $F_n$ tenemos que:
#
# $$ \frac{F_{n+1}}{F_n}=1+\frac{F_{n-1}}{F_n}$$
#
#
# Si se define $a_n=1+ \frac{1}{a_{n-1}}$ y $a_1=1$ Con $n \geq 2$
#
# Esta sucesión converge a la Razón aurea.
#
# Describa brevemente el significado de la proporción aurea
#
# **Responda**
#
# a. Determine el valor de  $𝛷$
#
# b. Escriba un pequeño informe acerca del significado del número $𝛷$ que incluya la relación entre este número y la forma del caparazón de cámaras múltiples del nautilo.

# %% [markdown]
# # Pregunta 4
#
# Un poco de historia: Muerte por pan En 1972, un brote de envenenamiento por metilmercurio en Irak produjo 459 muertes entre 6530 casos de envenenados admitidos en hospitales. El brote epidémico fue provocado por el consumo de pan
# casero preparado a partir de trigo que había sido tratado con un fungicida de metilmercurio. Los primeros síntomas de parestesia (pérdida de sensaciones en la boca, manos y pies) empezaron a ocurrir cuando el nivel acumulado de
# mercurio alcanzó 25 mg.
#
# Los síntomas de ataxia (pérdida de coordinación al andar) iniciaron con 55 mg, la dysarthia (arrastrar las palabras) con 90 mg y la sordera con 170 mg. La muerte se volvió una posibilidad cuando el nivel de mercurio acumulado superó 200 mg.
#
# Se estimó que una barra de pan típica elaborada a partir de trigo
# contaminado contenía 1.4 mg de mercurio, y también que el cuerpo elimina sólo alrededor de 0.9% del mercurio acumulado diariamente.
#
# a) Suponga que una persona recibió una dosis d de mercurio al día, y que el cuerpo eliminó una fracción p del mercurio acumulado diariamente. Encuentre una
# fórmula para $L_n$, el nivel acumulado después de comer en el n-ésimo día, y una fórmula para el nivel límite, $lim_{n → \infty} Ln$
#
# b) Empleando d =1.4 y p = 0.009, encuentre el valor límite del mercurio y determine qué día empezaron a ocurrir los diversos síntomas
#
# c) ¿Cuál sería la dosis diaria para que la muerte fuera
# posible en el día 100? (Utilice p = 0.009)
